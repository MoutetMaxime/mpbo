# %%
import torch

import numpy as np
import matplotlib.pyplot as plt

from BO import BayesianOptimizer
from ObjectiveFunction import ObjectiveFunction

# %%
obj = ObjectiveFunction("Ackley", dim=2)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 3

opt = BayesianOptimizer(search_space, response)
regret_gpbo, baseline = opt.train(
    kappa,
    initial_points=1,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Vanilla BO",
    save_file=True,
    file_name="Ackley_BO",
)

baseline, _ = baseline

regret_mpbo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="MP-BO",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Ackley_MPBO",
)

regret_fifo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="FiFo",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Ackley_FIFO",
)

regret_mean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Mean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Ackley_Mean",
)

regret_geomean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="GeoMean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Ackley_Geometric_Mean",
)

regret_worst, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Worst",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Ackley_Worst",
)
# Out:
# 100%|██████████| 30/30 [01:16<00:00,  2.54s/it]
# 100%|██████████| 30/30 [00:54<00:00,  1.82s/it]
# 100%|██████████| 30/30 [00:54<00:00,  1.83s/it]
# 100%|██████████| 30/30 [00:53<00:00,  1.79s/it]
#   0%|          | 0/30 [00:00<?, ?it/s]/Users/maximemoutet/.pyenv/versions/venv-internship/lib/python3.12/site-packages/scipy/stats/_stats_py.py:197: RuntimeWarning: invalid value encountered in log
#   log_a = np.log(a)
# 100%|██████████| 30/30 [00:53<00:00,  1.80s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.74s/it]

# %%
plt.plot(regret_gpbo.mean(0), linestyle="--", label="Vanilla BO", color="red")
plt.fill_between(
    range(150),
    regret_gpbo.mean(0) - regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    regret_gpbo.mean(0) + regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    color="red",
    alpha=0.2,
)
plt.plot(regret_mpbo.mean(0), label="MP-BO", color="tab:blue")
plt.fill_between(
    range(150),
    regret_mpbo.mean(0) - regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    regret_mpbo.mean(0) + regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    color="tab:blue",
    alpha=0.2,
)
plt.plot(regret_fifo.mean(0), label="FiFo", color="green", linestyle="-.")
plt.fill_between(
    range(150),
    regret_fifo.mean(0) - regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    regret_fifo.mean(0) + regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    color="green",
    alpha=0.2,
)
plt.plot(regret_mean.mean(0), label="Mean", color="orange", linestyle=(5, (10, 3)))
plt.fill_between(
    range(150),
    regret_mean.mean(0) - regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    regret_mean.mean(0) + regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    color="orange",
    alpha=0.2,
)
plt.plot(
    regret_geomean.mean(0), label="GeoMean", color="purple", linestyle=(0, (5, 10))
)
plt.fill_between(
    range(150),
    regret_geomean.mean(0) - regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    regret_geomean.mean(0) + regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    color="purple",
    alpha=0.2,
)

plt.plot(regret_worst.mean(0), label="Worst", color="grey", linestyle=":")
plt.fill_between(
    range(150),
    regret_worst.mean(0) - regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    regret_worst.mean(0) + regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    color="grey",
    alpha=0.2,
)
plt.vlines(20, 0, 1, colors="black", linestyles="dotted")
plt.legend()

# %%
obj = ObjectiveFunction("Michalewicz", dim=2)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 4

opt = BayesianOptimizer(search_space, response)
regret_gpbo, baseline = opt.train(
    kappa,
    initial_points=1,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Vanilla BO",
    save_file=True,
    file_name="Michalewicz2D_BO",
)
baseline, _ = baseline
regret_mpbo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="MP-BO",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Michalewicz2D_MPBO",
)

regret_fifo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="FiFo",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Michalewicz2D_FIFO",
)

regret_mean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Mean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Michalewicz2D_Mean",
)

regret_geomean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="GeoMean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Michalewicz2D_Geometric_Mean",
)

regret_worst, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Worst",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Michalewicz2D_Worst",
)
# Out:
# 100%|██████████| 30/30 [01:11<00:00,  2.38s/it]
# 100%|██████████| 30/30 [00:54<00:00,  1.80s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.76s/it]
# 100%|██████████| 30/30 [00:51<00:00,  1.71s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.74s/it]
# 100%|██████████| 30/30 [00:51<00:00,  1.71s/it]

# %%
plt.plot(regret_gpbo.mean(0), linestyle="--", label="Vanilla BO", color="red")
plt.fill_between(
    range(150),
    regret_gpbo.mean(0) - regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    regret_gpbo.mean(0) + regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    color="red",
    alpha=0.2,
)
plt.plot(regret_mpbo.mean(0), label="MP-BO", color="tab:blue")
plt.fill_between(
    range(150),
    regret_mpbo.mean(0) - regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    regret_mpbo.mean(0) + regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    color="tab:blue",
    alpha=0.2,
)
plt.plot(regret_fifo.mean(0), label="FiFo", color="green", linestyle="-.")
plt.fill_between(
    range(150),
    regret_fifo.mean(0) - regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    regret_fifo.mean(0) + regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    color="green",
    alpha=0.2,
)
plt.plot(regret_mean.mean(0), label="Mean", color="orange", linestyle=(5, (10, 3)))
plt.fill_between(
    range(150),
    regret_mean.mean(0) - regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    regret_mean.mean(0) + regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    color="orange",
    alpha=0.2,
)
plt.plot(
    regret_geomean.mean(0), label="GeoMean", color="purple", linestyle=(0, (5, 10))
)
plt.fill_between(
    range(150),
    regret_geomean.mean(0) - regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    regret_geomean.mean(0) + regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    color="purple",
    alpha=0.2,
)

plt.plot(regret_worst.mean(0), label="Worst", color="grey", linestyle=":")
plt.fill_between(
    range(150),
    regret_worst.mean(0) - regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    regret_worst.mean(0) + regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    color="grey",
    alpha=0.2,
)
plt.vlines(20, 0, 1, colors="black", linestyles="dotted")
plt.legend()

# %%
obj = ObjectiveFunction("Michalewicz", dim=4)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 5

opt = BayesianOptimizer(search_space, response)
regret_gpbo, baseline = opt.train(
    kappa,
    initial_points=1,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Vanilla BO",
    save_file=True,
    file_name="Michalewicz4D_BO",
)

bo_follow, _ = baseline
regret_mpbo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="MP-BO",
    begin_strat=20,
    initial_points=20,
    follow_baseline=bo_follow,
    save_file=True,
    file_name="Michalewicz4D_MPBO",
)

regret_fifo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="FiFo",
    begin_strat=20,
    initial_points=20,
    follow_baseline=bo_follow,
    save_file=True,
    file_name="Michalewicz4D_FIFO",
)

regret_mean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Mean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=bo_follow,
    save_file=True,
    file_name="Michalewicz4D_Mean",
)

regret_geomean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="GeoMean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=bo_follow,
    save_file=True,
    file_name="Michalewicz4D_Geometric_Mean",
)


regret_worst, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    strategy="Worst",
    begin_strat=20,
    initial_points=20,
    follow_baseline=bo_follow,
    save_file=True,
    file_name="Michalewicz4D_Worst",
)
# Out:
# 100%|██████████| 30/30 [01:33<00:00,  3.12s/it]
# 100%|██████████| 30/30 [00:58<00:00,  1.94s/it]
# 100%|██████████| 30/30 [00:55<00:00,  1.86s/it]
# 100%|██████████| 30/30 [00:56<00:00,  1.87s/it]
# 100%|██████████| 30/30 [00:57<00:00,  1.93s/it]
# 100%|██████████| 30/30 [00:57<00:00,  1.90s/it]

# %%
bo_follow, _ = baseline
# regret_mpbo, _ = opt.train(
#     kappa,
#     repetitions=30,
#     iterations=150,
#     training_iter=10,
#     strategy="MP-BO",
#     begin_strat=20,
#     initial_points=20,
#     follow_baseline=bo_follow,
#     save_file=True,
#     file_name="Michalewicz4D_MPBO",
# )

# regret_fifo, _ = opt.train(
#     kappa,
#     repetitions=30,
#     iterations=150,
#     training_iter=10,
#     strategy="FiFo",
#     begin_strat=20,
#     initial_points=20,
#     follow_baseline=bo_follow,
#     save_file=True,
#     file_name="Michalewicz4D_FIFO",
# )

# regret_mean, _ = opt.train(
#     kappa,
#     repetitions=30,
#     iterations=150,
#     training_iter=10,
#     strategy="Mean",
#     begin_strat=20,
#     initial_points=20,
#     follow_baseline=bo_follow,
#     save_file=True,
#     file_name="Michalewicz4D_Mean",
# )

# regret_geomean, _ = opt.train(
#     kappa,
#     repetitions=30,
#     iterations=150,
#     training_iter=10,
#     strategy="GeoMean",
#     begin_strat=20,
#     initial_points=20,
#     follow_baseline=bo_follow,
#     save_file=True,
#     file_name="Michalewicz4D_Geometric_Mean",
# )


regret_worst, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    strategy="Worst",
    begin_strat=60,
    initial_points=1,
    # follow_baseline=bo_follow,
    save_file=True,
    file_name="Michalewicz4D_Worst",
)
# Out:
# 100%|██████████| 30/30 [01:12<00:00,  2.43s/it]

# %%
bo_follow, _ = baseline


__, __ = opt.train(
    kappa,
    initial_points=1,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Vanilla BO",
)

for i in range(10):
    regret_worst, _ = opt.train(
        kappa,
        repetitions=30,
        iterations=150,
        training_iter=10,
        strategy="Worst",
        begin_strat=20,
        initial_points=1,
        follow_baseline=bo_follow,
        save_file=True,
        file_name="Michalewicz4D_Worst",
    )
    plt.plot(regret_worst.mean(0), label="Worst", color="grey", linestyle=":")
    plt.show()
# Out:
#   3%|▎         | 1/30 [00:05<02:31,  5.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 4
#       1 bo_follow, _ = baseline
# ----> 4 __, __ = opt.train(
#       5     kappa,
#       6     initial_points=1,
#       7     repetitions=30,
#       8     iterations=150,
#       9     training_iter=10,
#      10     strategy="Vanilla BO",
#      11 )
#      13 for i in range(10):
#      14     regret_worst, _ = opt.train(
#      15         kappa,
#      16         repetitions=30,
#    (...)
#      24         file_name="Michalewicz4D_Worst",
#      25     )
#
# File ~/Documents/X/3A/Stage/code/mpbo/BO.py:231, in BayesianOptimizer.train(self, kappa, initial_points, repetitions, iterations, training_iter, strategy, begin_strat, follow_baseline, baseline_bests, save_file, file_name)
#     228 model.train()
#     229 likelihood.train()
# --> 231 model, likelihood = optimize(
#     232     model,
#     233     likelihood,
#     234     training_iter,
#     235     train_x,
#     236     train_y,
#     237     verbose=False,
#     238 )
#     240 model.eval()
#     241 likelihood.eval()
#
# File ~/Documents/X/3A/Stage/code/mpbo/model.py:29, in optimize(model, likelihood, training_iter, train_x, train_y, verbose)
#      27 optimizer.zero_grad()
#      28 # Output from model
# ---> 29 output = model(train_x)
#      31 # Calc loss and backprop gradients
#      32 loss = -mll(output, train_y)
#
# File ~/.pyenv/versions/venv-internship/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:263, in ExactGP.__call__(self, *args, **kwargs)
#     258 if self.train_inputs is None:
#     259     raise RuntimeError(
#     260         "train_inputs, train_targets cannot be None in training mode. "
#     261         "Call .eval() for prior predictions, or call .set_train_data() to add training data."
#     262     )
# --> 263 if settings.debug.on():
#     264     if not all(
#     265         torch.equal(train_input, input) for train_input, input in length_safe_zip(train_inputs, inputs)
#     266     ):
#     267         raise RuntimeError("You must train on the training inputs!")
#
# File ~/.pyenv/versions/venv-internship/lib/python3.12/site-packages/gpytorch/settings.py:93, in _feature_flag.on(cls)
#      89 @classmethod
#      90 def is_default(cls):
#      91     return cls._state is None
# ---> 93 @classmethod
#      94 def on(cls):
#      95     if cls.is_default():
#      96         return cls._default
#
# KeyboardInterrupt:

# %%
plt.plot(regret_gpbo.mean(0), linestyle="--", label="Vanilla BO", color="red")
plt.fill_between(
    range(150),
    regret_gpbo.mean(0) - regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    regret_gpbo.mean(0) + regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    color="red",
    alpha=0.2,
)

plt.plot(regret_worst.mean(0), label="Worst", color="orange", linestyle=":")
plt.fill_between(
    range(150),
    regret_worst.mean(0) - regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    regret_worst.mean(0) + regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    color="orange",
    alpha=0.2,
)
plt.plot(regret_mpbo.mean(0), label="MP-BO", color="tab:blue")
plt.fill_between(
    range(150),
    regret_mpbo.mean(0) - regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    regret_mpbo.mean(0) + regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    color="tab:blue",
    alpha=0.2,
)
plt.plot(regret_fifo.mean(0), label="FiFo", color="green", linestyle="-.")
plt.fill_between(
    range(150),
    regret_fifo.mean(0) - regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    regret_fifo.mean(0) + regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    color="green",
    alpha=0.2,
)
plt.plot(regret_mean.mean(0), label="Mean", color="orange", linestyle=(5, (10, 3)))
plt.fill_between(
    range(150),
    regret_mean.mean(0) - regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    regret_mean.mean(0) + regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    color="orange",
    alpha=0.2,
)
plt.plot(
    regret_geomean.mean(0), label="GeoMean", color="purple", linestyle=(0, (5, 10))
)
plt.fill_between(
    range(150),
    regret_geomean.mean(0) - regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    regret_geomean.mean(0) + regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    color="purple",
    alpha=0.2,
)


plt.vlines(20, 0, 1, colors="black", linestyles="dotted")
plt.legend()

# %%
obj = ObjectiveFunction("Hartmann", dim=6)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 5

opt = BayesianOptimizer(search_space, response)
regret_gpbo, baseline = opt.train(
    kappa,
    initial_points=1,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Vanilla BO",
    begin_strat=20,
    save_file=True,
    file_name="Hartmann6D_BO",
)

baseline, _ = baseline
regret_mpbo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="MP-BO",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Hartmann6D_MPBO",
)

regret_fifo, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="FiFo",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Hartmann6D_FIFO",
)

regret_mean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Mean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Hartmann6D_Mean",
)

regret_geomean, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="GeoMean",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Hartmann6D_Geometric_Mean",
)

regret_worst, _ = opt.train(
    kappa,
    repetitions=30,
    iterations=150,
    training_iter=10,
    strategy="Worst",
    begin_strat=20,
    initial_points=20,
    follow_baseline=baseline,
    save_file=True,
    file_name="Hartmann6D_Worst",
)
# Out:
# 100%|██████████| 30/30 [02:01<00:00,  4.04s/it]
# 100%|██████████| 30/30 [01:08<00:00,  2.30s/it]
# 100%|██████████| 30/30 [01:04<00:00,  2.15s/it]
# 100%|██████████| 30/30 [01:05<00:00,  2.17s/it]
#  90%|█████████ | 27/30 [00:58<00:06,  2.14s/it]/Users/maximemoutet/.pyenv/versions/venv-internship/lib/python3.12/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning: Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-06.
#   warnings.warn(
# 100%|██████████| 30/30 [01:05<00:00,  2.17s/it]
# 100%|██████████| 30/30 [01:04<00:00,  2.13s/it]

# %%
plt.plot(regret_gpbo.mean(0), linestyle="--", label="Vanilla BO", color="red")
plt.fill_between(
    range(150),
    regret_gpbo.mean(0) - regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    regret_gpbo.mean(0) + regret_gpbo.std(0) / np.sqrt(regret_gpbo.shape[0]),
    color="red",
    alpha=0.2,
)
plt.plot(regret_mpbo.mean(0), label="MP-BO", color="tab:blue")
plt.fill_between(
    range(150),
    regret_mpbo.mean(0) - regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    regret_mpbo.mean(0) + regret_mpbo.std(0) / np.sqrt(regret_mpbo.shape[0]),
    color="tab:blue",
    alpha=0.2,
)
plt.plot(regret_fifo.mean(0), label="FiFo", color="green", linestyle="-.")
plt.fill_between(
    range(150),
    regret_fifo.mean(0) - regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    regret_fifo.mean(0) + regret_fifo.std(0) / np.sqrt(regret_fifo.shape[0]),
    color="green",
    alpha=0.2,
)
plt.plot(regret_mean.mean(0), label="Mean", color="orange", linestyle=(5, (10, 3)))
plt.fill_between(
    range(150),
    regret_mean.mean(0) - regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    regret_mean.mean(0) + regret_mean.std(0) / np.sqrt(regret_mean.shape[0]),
    color="orange",
    alpha=0.2,
)
plt.plot(
    regret_geomean.mean(0), label="GeoMean", color="purple", linestyle=(0, (5, 10))
)
plt.fill_between(
    range(150),
    regret_geomean.mean(0) - regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    regret_geomean.mean(0) + regret_geomean.std(0) / np.sqrt(regret_geomean.shape[0]),
    color="purple",
    alpha=0.2,
)

plt.plot(regret_worst.mean(0), label="Worst", color="grey", linestyle=":")
plt.fill_between(
    range(150),
    regret_worst.mean(0) - regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    regret_worst.mean(0) + regret_worst.std(0) / np.sqrt(regret_worst.shape[0]),
    color="grey",
    alpha=0.2,
)
plt.vlines(20, 0, 1, colors="black", linestyles="dotted")
plt.legend()

# %% [markdown]
# Ackley:

# %%
q_stars = np.arange(2, 62, 2)

obj = ObjectiveFunction("Ackley", dim=2)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 3

opt = BayesianOptimizer(search_space, response)

all_regret_gpbo = np.zeros((len(q_stars), 30, 150))
all_regret_mpbo = np.zeros((len(q_stars), 30, 150))
# all_regret_fifo = np.zeros((len(q_stars), 30, 150))

for q_star in q_stars:
    print("q* =", q_star)
    regret_gpbo, baseline = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        strategy="Vanilla BO",
    )

    regret_mpbo, _ = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        training_iter=10,
        strategy="MP-BO",
        begin_strat=q_star,
    )

    # regret_fifo, _ = opt.train(
    #     kappa,
    #     repetitions=30,
    #     iterations=150,
    #     training_iter=10,
    #     strategy="FiFo",
    #     begin_strat=q_star,
    #     initial_points=q_star,
    #     follow_baseline=baseline,
    # )

    all_regret_gpbo[q_star // 2 - 1] = regret_gpbo
    all_regret_mpbo[q_star // 2 - 1] = regret_mpbo
    # all_regret_fifo[q_star // 2 - 1] = regret_fifo

np.savez(
    "outpus/Ackley_varyq_bo_mpbo.npz",
    q_stars=q_stars,
    regret_gpbo=all_regret_gpbo,
    regret_mpbo=all_regret_mpbo,
    # regret_fifo=all_regret_fifo,
)
# Out:
# q* = 2
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:46<00:00,  1.56s/it]
# q* = 4
# 100%|██████████| 30/30 [01:10<00:00,  2.36s/it]
# 100%|██████████| 30/30 [00:47<00:00,  1.59s/it]
# q* = 6
# 100%|██████████| 30/30 [01:10<00:00,  2.34s/it]
# 100%|██████████| 30/30 [00:47<00:00,  1.60s/it]
# q* = 8
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:48<00:00,  1.62s/it]
# q* = 10
# 100%|██████████| 30/30 [01:10<00:00,  2.36s/it]
# 100%|██████████| 30/30 [00:49<00:00,  1.66s/it]
# q* = 12
# 100%|██████████| 30/30 [01:09<00:00,  2.32s/it]
# 100%|██████████| 30/30 [00:48<00:00,  1.62s/it]
# q* = 14
# 100%|██████████| 30/30 [01:10<00:00,  2.36s/it]
# 100%|██████████| 30/30 [00:49<00:00,  1.65s/it]
# q* = 16
# 100%|██████████| 30/30 [01:09<00:00,  2.31s/it]
# 100%|██████████| 30/30 [00:49<00:00,  1.65s/it]
# q* = 18
# 100%|██████████| 30/30 [01:10<00:00,  2.33s/it]
# 100%|██████████| 30/30 [00:50<00:00,  1.68s/it]
# q* = 20
# 100%|██████████| 30/30 [01:11<00:00,  2.37s/it]
# 100%|██████████| 30/30 [00:50<00:00,  1.68s/it]
# q* = 22
# 100%|██████████| 30/30 [01:09<00:00,  2.32s/it]
# 100%|██████████| 30/30 [00:50<00:00,  1.67s/it]
# q* = 24
# 100%|██████████| 30/30 [01:10<00:00,  2.35s/it]
# 100%|██████████| 30/30 [00:51<00:00,  1.73s/it]
# q* = 26
# 100%|██████████| 30/30 [01:12<00:00,  2.40s/it]
# 100%|██████████| 30/30 [00:51<00:00,  1.70s/it]
# q* = 28
# 100%|██████████| 30/30 [01:10<00:00,  2.35s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.75s/it]
# q* = 30
# 100%|██████████| 30/30 [01:10<00:00,  2.34s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.74s/it]
# q* = 32
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.76s/it]
# q* = 34
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:53<00:00,  1.77s/it]
# q* = 36
# 100%|██████████| 30/30 [01:10<00:00,  2.35s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.77s/it]
# q* = 38
# 100%|██████████| 30/30 [01:12<00:00,  2.42s/it]
# 100%|██████████| 30/30 [00:53<00:00,  1.79s/it]
# q* = 40
# 100%|██████████| 30/30 [01:10<00:00,  2.36s/it]
# 100%|██████████| 30/30 [00:53<00:00,  1.77s/it]
# q* = 42
# 100%|██████████| 30/30 [01:09<00:00,  2.32s/it]
# 100%|██████████| 30/30 [00:53<00:00,  1.78s/it]
# q* = 44
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:53<00:00,  1.80s/it]
# q* = 46
# 100%|██████████| 30/30 [01:08<00:00,  2.29s/it]
# 100%|██████████| 30/30 [00:57<00:00,  1.93s/it]
# q* = 48
# 100%|██████████| 30/30 [01:10<00:00,  2.36s/it]
# 100%|██████████| 30/30 [00:58<00:00,  1.93s/it]
# q* = 50
# 100%|██████████| 30/30 [01:10<00:00,  2.34s/it]
# 100%|██████████| 30/30 [00:57<00:00,  1.92s/it]
# q* = 52
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:58<00:00,  1.96s/it]
# q* = 54
# 100%|██████████| 30/30 [01:12<00:00,  2.42s/it]
# 100%|██████████| 30/30 [00:59<00:00,  1.99s/it]
# q* = 56
# 100%|██████████| 30/30 [01:10<00:00,  2.35s/it]
# 100%|██████████| 30/30 [00:59<00:00,  2.00s/it]
# q* = 58
# 100%|██████████| 30/30 [01:12<00:00,  2.41s/it]
# 100%|██████████| 30/30 [00:59<00:00,  1.99s/it]
# q* = 60
# 100%|██████████| 30/30 [01:12<00:00,  2.41s/it]
# 100%|██████████| 30/30 [00:59<00:00,  1.97s/it]

# %%
q_stars = np.arange(2, 62, 2)

obj = ObjectiveFunction("Michalewicz", dim=2)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 4

opt = BayesianOptimizer(search_space, response)

all_regret_gpbo = np.zeros((30, 150))
all_regret_mpbo = np.zeros((len(q_stars), 30, 150))
# all_regret_fifo = np.zeros((len(q_stars), 30, 150))

for q_star in q_stars:
    print("q* =", q_star)
    regret_gpbo, baseline = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        strategy="Vanilla BO",
    )

    regret_mpbo, _ = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        training_iter=10,
        strategy="MP-BO",
        begin_strat=q_star,
    )

    # regret_fifo, _ = opt.train(
    #     kappa,
    #     repetitions=30,
    #     iterations=150,
    #     training_iter=10,
    #     strategy="FiFo",
    #     begin_strat=q_star,
    #     initial_points=q_star,
    #     follow_baseline=baseline,
    # )

    all_regret_mpbo[q_star // 2 - 1] = regret_mpbo
    # all_regret_fifo[q_star // 2 - 1] = regret_fifo

np.savez(
    "Michalewicz2D_varyq.npz",
    q_stars=q_stars,
    regret_gpbo=regret_gpbo,
    regret_mpbo=all_regret_mpbo,
    # regret_fifo=all_regret_fifo,
)
# Out:
# q* = 2
# 100%|██████████| 30/30 [01:08<00:00,  2.28s/it]
# 100%|██████████| 30/30 [00:56<00:00,  1.87s/it]
# q* = 48
# 100%|██████████| 30/30 [01:09<00:00,  2.33s/it]
# 100%|██████████| 30/30 [00:57<00:00,  1.92s/it]
# q* = 50
# 100%|██████████| 30/30 [01:15<00:00,  2.52s/it]
# 100%|██████████| 30/30 [01:01<00:00,  2.03s/it]
# q* = 52
# 100%|██████████| 30/30 [01:12<00:00,  2.41s/it]
# 100%|██████████| 30/30 [01:02<00:00,  2.08s/it]
# q* = 54
# 100%|██████████| 30/30 [01:12<00:00,  2.41s/it]
# 100%|██████████| 30/30 [01:00<00:00,  2.03s/it]
# q* = 56
# 100%|██████████| 30/30 [01:08<00:00,  2.30s/it]
# 100%|██████████| 30/30 [00:59<00:00,  1.97s/it]
# q* = 58
# 100%|██████████| 30/30 [01:09<00:00,  2.31s/it]
# 100%|██████████| 30/30 [01:00<00:00,  2.02s/it]
# q* = 60
# 100%|██████████| 30/30 [01:11<00:00,  2.39s/it]
# 100%|██████████| 30/30 [00:59<00:00,  1.97s/it]

# %%
q_stars = np.arange(2, 62, 2)

obj = ObjectiveFunction("Michalewicz", dim=4)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 5

opt = BayesianOptimizer(search_space, response)

all_regret_gpbo = np.zeros((30, 150))
all_regret_mpbo = np.zeros((len(q_stars), 30, 150))
all_regret_fifo = np.zeros((len(q_stars), 30, 150))

for q_star in q_stars:
    print("q* =", q_star)

    regret_gpbo, baseline = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        strategy="Vanilla BO",
    )

    # baseline, baseline_bests = baseline

    regret_mpbo, _ = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        strategy="MP-BO",
        begin_strat=q_star,
    )

    # regret_fifo, _ = opt.train(
    #     kappa,
    #     repetitions=30,
    #     iterations=150,
    #     training_iter=10,
    #     strategy="FiFo",
    #     begin_strat=q_star,
    #     initial_points=q_star,
    #     follow_baseline=baseline,
    # )

    all_regret_mpbo[q_star // 2 - 1] = regret_mpbo
    # all_regret_fifo[q_star // 2 - 1] = regret_fifo

    # plt.plot(regret_gpbo.mean(0), linestyle="--", label="Vanilla BO", color="red")
    # plt.plot(regret_mpbo.mean(0), label="MP-BO", color="tab:blue")
    # plt.plot(regret_fifo.mean(0), label="FiFo", color="green")
    # plt.vlines(q_star, 0, 1, colors="black", linestyles="dotted")
    # plt.show()

np.savez(
    "outpus/Michalewicz4D_varyq_bo_mpbo.npz",
    q_stars=q_stars,
    regret_gpbo=regret_gpbo,
    regret_mpbo=all_regret_mpbo,
    # regret_fifo=all_regret_fifo,
)
# Out:
# q* = 2
# 100%|██████████| 30/30 [01:42<00:00,  3.41s/it]
# 100%|██████████| 30/30 [00:51<00:00,  1.71s/it]
# q* = 4
# 100%|██████████| 30/30 [01:37<00:00,  3.26s/it]
# 100%|██████████| 30/30 [00:52<00:00,  1.76s/it]
# q* = 6
# 100%|██████████| 30/30 [01:40<00:00,  3.35s/it]
# 100%|██████████| 30/30 [00:58<00:00,  1.95s/it]
# q* = 8
# 100%|██████████| 30/30 [01:30<00:00,  3.01s/it]
# 100%|██████████| 30/30 [01:12<00:00,  2.43s/it]
# q* = 54
# 100%|██████████| 30/30 [01:29<00:00,  3.00s/it]
# 100%|██████████| 30/30 [01:13<00:00,  2.46s/it]
# q* = 56
# 100%|██████████| 30/30 [01:33<00:00,  3.13s/it]
# 100%|██████████| 30/30 [01:14<00:00,  2.47s/it]
# q* = 58
# 100%|██████████| 30/30 [01:31<00:00,  3.07s/it]
# 100%|██████████| 30/30 [01:14<00:00,  2.49s/it]
# q* = 60
# 100%|██████████| 30/30 [01:34<00:00,  3.15s/it]
# 100%|██████████| 30/30 [01:17<00:00,  2.57s/it]

# %%
q_stars = np.arange(2, 62, 2)

obj = ObjectiveFunction("Hartmann", dim=6)
search_space = obj.create_input_space()
response = obj.generate_true_response(search_space)
kappa = 5

opt = BayesianOptimizer(search_space, response)

all_regret_gpbo = np.zeros((30, 150))
all_regret_mpbo = np.zeros((len(q_stars), 30, 150))
# all_regret_fifo = np.zeros((len(q_stars), 30, 150))

for q_star in q_stars:
    print("q* =", q_star)
    regret_gpbo, baseline = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        strategy="Vanilla BO",
    )

    regret_mpbo, _ = opt.train(
        kappa,
        initial_points=1,
        repetitions=30,
        iterations=150,
        training_iter=10,
        strategy="MP-BO",
        begin_strat=q_star,
    )

    # regret_fifo, _ = opt.train(
    #     kappa,
    #     repetitions=30,
    #     iterations=150,
    #     training_iter=10,
    #     strategy="FiFo",
    #     begin_strat=q_star,
    #     initial_points=q_star,
    #     follow_baseline=baseline,
    # )

    all_regret_mpbo[q_star // 2 - 1] = regret_mpbo
    # all_regret_fifo[q_star // 2 - 1] = regret_fifo

np.savez(
    "outpus/Hartmann6D_varyq_bo_mpbo.npz",
    q_stars=q_stars,
    regret_gpbo=regret_gpbo,
    regret_mpbo=all_regret_mpbo,
    # regret_fifo=all_regret_fifo,
)
# Out:
# q* = 2
# 100%|██████████| 30/30 [01:55<00:00,  3.86s/it]
# 100%|██████████| 30/30 [00:58<00:00,  1.97s/it]
# q* = 4
# 100%|██████████| 30/30 [01:55<00:00,  3.84s/it]
# 100%|██████████| 30/30 [00:59<00:00,  1.98s/it]
# q* = 6
# 100%|██████████| 30/30 [01:58<00:00,  3.94s/it]
# 100%|██████████| 30/30 [01:02<00:00,  2.10s/it]
# q* = 8
# 100%|██████████| 30/30 [02:02<00:00,  4.10s/it]
# 100%|██████████| 30/30 [01:02<00:00,  2.07s/it]
# q* = 10
# 100%|██████████| 30/30 [01:57<00:00,  3.91s/it]
# 100%|██████████| 30/30 [01:04<00:00,  2.13s/it]
# q* = 12
# 100%|██████████| 30/30 [02:00<00:00,  4.00s/it]
# 100%|██████████| 30/30 [01:07<00:00,  2.24s/it]
# q* = 14
# 100%|██████████| 30/30 [01:59<00:00,  3.97s/it]
# 100%|██████████| 30/30 [01:03<00:00,  2.13s/it]
# q* = 16
# 100%|██████████| 30/30 [01:55<00:00,  3.87s/it]
# 100%|██████████| 30/30 [01:06<00:00,  2.21s/it]
